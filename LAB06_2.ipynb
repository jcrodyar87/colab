# %%
#PASO 1
#Ingresar al ruta de la pagina donde se encuentra el dataset
#Ir a RULES (Reglas)
#Aceptar la competicion

#Ejemplos:
#https://www.kaggle.com/competitions/titanic
#https://www.kaggle.com/competitions/stable-diffusion-image-to-prompts
#https://www.kaggle.com/competitions/forest-cover-type-prediction

#PASO 2
#Descarga de usuario y password de acceso
#Ir a https://www.kaggle.com/
#Ir a icono de Perfil de Usuario
#Ir a Settings o Configuraciones
#En seccion API: Descargar en: CREATE NEW TOKEN
#El archivo descargado contiene información de usuario y password para acceder a los datasets

# %%
# !pip install opendatasets
import opendatasets as od

# %%
#Asignar a dataset_link el link de los datos que se desean importar
dataset_link="https://www.kaggle.com/competitions/stable-diffusion-image-to-prompts"
od.download(dataset_link)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: mmacavilca
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 3.04M/3.04M [00:00<00:00, 170MB/s]
# Extracting archive ./stable-diffusion-image-to-prompts/stable-diffusion-image-to-prompts.zip to ./stable-diffusion-image-to-prompts

# %%
#Copiar ruta donde se cargaron los archivos
import os
os.chdir("stable-diffusion-image-to-prompts")
os.listdir()
# Out:
# ['images', 'sample_submission.csv', 'prompts.csv']

# %%
#Mostrar un archivo cargado de la lista
import pandas as pd
archivo="prompts.csv"
df1=pd.read_csv(archivo)
df1
# Out:
#        imgId                                             prompt
# 0  20057f34d  hyper realistic photo of very friendly and dys...
# 1  227ef0887  ramen carved out of fractal rose ebony, in the...
# 2  92e911621  ultrasaurus holding a black bean taco in the w...
# 3  a4e1c55a9  a thundering retro robot crane inks on parchme...
# 4  c98f79f71  portrait painting of a shimmering greek hero, ...
# 5  d8edf2e40  an astronaut standing on a engaging white rose...
# 6  f27825b2c  Kaggle employee Phil at a donut shop ordering ...

# %%
#Los 20 primeros
df1.head(20)
# Out:
#        imgId                                             prompt
# 0  20057f34d  hyper realistic photo of very friendly and dys...
# 1  227ef0887  ramen carved out of fractal rose ebony, in the...
# 2  92e911621  ultrasaurus holding a black bean taco in the w...
# 3  a4e1c55a9  a thundering retro robot crane inks on parchme...
# 4  c98f79f71  portrait painting of a shimmering greek hero, ...
# 5  d8edf2e40  an astronaut standing on a engaging white rose...
# 6  f27825b2c  Kaggle employee Phil at a donut shop ordering ...

# %%
# Filtra el DataFrame por la columna "PROMPT" y la condición "astronaut"
df_filtrado = df1[df1['prompt'].str.contains("astronaut", case=False)]
df_filtrado
# Out:
#        imgId                                             prompt
# 5  d8edf2e40  an astronaut standing on a engaging white rose...

# %%
archivo2="sample_submission.csv"
pd.read_csv(archivo2)
# Out:
#           imgId_eId       val
# 0       20057f34d_0  0.018848
# 1       20057f34d_1  0.030190
# 2       20057f34d_2  0.072792
# 3       20057f34d_3 -0.000673
# 4       20057f34d_4  0.016774
# ...             ...       ...
# 2683  f27825b2c_379  0.012124
# 2684  f27825b2c_380  0.021575
# 2685  f27825b2c_381  0.030563
# 2686  f27825b2c_382  0.014047
# 2687  f27825b2c_383  0.023764
#
# [2688 rows x 2 columns]
