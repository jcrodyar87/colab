# %% [markdown]
# <img src="https://raw.githubusercontent.com/sebastianVP/sebastianVP/main/toulouselautrec_logo.jpg" alt= "LOGO CAT" width=400 height=400 align = "right">
#
# <br>
# <h1><font color="#7F000E" size=5>TOULOUSE LAUTREC </font></h1>
# <h1><font color="#7F000R" size=6> METODOLOGÍAS EN LA CIENCIA DE DATOS </font></h1>
# <h1><font color="#7F000E" size=4> De la comprensión a la Preparación -  Guia Practica
#  </font></h1>
# <br>
# <br>
# <div style="text-align:right">
# <font color="#7F000E" size=3> Ing. Alexander Valdez</font><br>
# <font color="#7F000E" size=3> Curso 2128, Clases Lunes y Miercoles 20:00-22:30pm </font><br>
# <font color="#7F000e" size=3> Tercera Sesión </font><br>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# #  METODOLOGIA  DE CIENCIA DE DATOS
#
# ## A. DEL PROBLEMA AL ENFOQUE
# - Comprensión del negocio
# - Enfoque Analítico
# - Caso de estudio
#
# ## B. De requerimientos a Colección
# - Requerimiento de datos
# - Recopilación de datos
# - Caso de estudio.
#
# ## C. De la comprensión a la preparación
# - Comprensión de datos
# - Preparáción de datos
# - Caso de estudio
#
# ## D. Del Modelado a la Evaluación
# - Modelamiento de datos
# - Evaluación del modelo
# - Caso de estudio
#
# ## E. De la implementación al feedback
# - Implementación del modelo
# - Retroalimentacion
# - Caso de estudio.

# %% [markdown]
# # GUIA PRACTICA: CICLO DE VIDA DE UN PROYECTO DE CIENCIA DE DATOS
#
# ## Motivación
#
# Con la creciente demanda de científicos de datos, más personas están dispuestas a ingresar a este campo. Se ha vuelto muy importante mostrar las habilidades adecuadas para destacar entre la multitud y ubicarse en las mejores empresas. Aquí es donde entran en juego los proyectos. Además, los proyectos de un extremo a otro le brindan exposición a un entorno de trabajo en tiempo real. En esta guía, explicaremos el ciclo de vida completo de un proyecto de ciencia de datos con una demostración práctica. Tomaremos un planteamiento de problema de aprendizaje automático y crearemos una aplicación web como solución utilizando Flask y la implementaremos en Heroku, una plataforma de aplicaciones en la nube. **¡Empecemos!**

# %% [markdown]
# # 1. COMPRENDER EL PROBLEMA

# %% [markdown]
# > Añadir blockquote
#
#
# El ciclo de vida de un proyecto comienza con la comprensión del planteamiento del problema. El planteamiento del problema (fuente) del proyecto es: **Predicción del ganador del mundial Qatar 2022.**

# %% [markdown]
# **Caso de Estudio**

# %% [markdown]
# ![metodologia.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # 2. RECOPILACION DE DATOS RELEVANTES

# %% [markdown]
# En esta sesión, vamos a hacer web scraping a todos los partidos de fútbol de las copas del mundo desde 1930 a 2018 y extraer el fixture de la Copa del Mundo Qatar 2022. Usaremos Python y BeautifulSoup.

# %% [markdown]
# **Fecha de los mundiales**

# %%
years = []
for i in range(1930,2022,4):
  years.append(i)
print(years)
len(years)
# Out:
# [1930, 1934, 1938, 1942, 1946, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018]
# 23

# %%
# EJENPLO 2014
link =  'https://en.wikipedia.org/wiki/2014_FIFA_World_Cup' # ver link

# NECESITAMOS HACER AHORA UN REQUEST

# %%
import requests

response = requests.get(link)
content =  response.text

print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>2014 FIFA World Cup - Wikipedia</title>
# ...

# %%
from bs4 import BeautifulSoup
soup= BeautifulSoup(content,'lxml') # definicion del parser

#print(soup)
#find: encontrar un elemento con el nombre de tag
#find_all
matches = soup.find_all('div',class_='footballbox')
print(len(matches))
print(matches[0])
# Out:
# 64
# <div class="footballbox" itemscope="" itemtype="http://schema.org/SportsEvent">
# <div class="fleft"><time><div class="fdate">12 June 2014</div><div class="ftime">17:00 <a href="/wiki/Time_in_Brazil" title="Time in Brazil">BRT</a> (<a href="/wiki/UTC%E2%88%9203:00" title="UTC−03:00">UTC−3</a>)</div></time></div><table class="fevent"><tbody><tr itemprop="name">
# ...

# %%
for match in matches:
  print(match.find('th',class_='fhome').get_text())
  print(match.find('th',class_='fscore').get_text())
  print(match.find('th',class_='faway').get_text())
  print("-----------------------------------------")
# Out:
# Brazil
# 3–1
#  Croatia
# -----------------------------------------
# Mexico
# 1–0
#  Cameroon
# -----------------------------------------
# Brazil
# 0–0
#  Mexico
# -----------------------------------------
# Cameroon
# 0–4
#  Croatia
# -----------------------------------------
# Cameroon
# 1–4
#  Brazil
# -----------------------------------------
# Croatia
# 1–3
#  Mexico
# -----------------------------------------
# Spain
# 1–5
#  Netherlands
# -----------------------------------------
# Chile
# 3–1
#  Australia
# -----------------------------------------
# Australia
# 2–3
#  Netherlands
# -----------------------------------------
# Spain
# 0–2
#  Chile
# -----------------------------------------
# Australia
# 0–3
#  Spain
# -----------------------------------------
# Netherlands
# 2–0
#  Chile
# -----------------------------------------
# Colombia
# 3–0
#  Greece
# -----------------------------------------
# Ivory Coast
# 2–1
#  Japan
# -----------------------------------------
# ...

# %% [markdown]
# Ahora vamos a colocar esta informacion en un dataframe, y un dataframe es un tabla en excel, que contiene la informacion en filas y columnas de manera mas eficiente para ello utilizaremos pandas.

# %%
import pandas as pd

# %% [markdown]
# Vamos a almacenar la informacion en listas

# %%
home=[]
score= []
away = [] # visita :)

for match in matches:
  home.append(match.find('th',class_='fhome').get_text())
  score.append(match.find('th',class_='fscore').get_text())
  away.append(match.find('th',class_='faway').get_text())

# %%
score
# Out:
# ['3–1',
#  '1–0',
#  '0–0',
#  '0–4',
#  '1–4',
#  '1–3',
#  '1–5',
#  '3–1',
#  '2–3',
#  '0–2',
#  '0–3',
#  '2–0',
#  '3–0',
#  '2–1',
#  '2–1',
#  '0–0',
#  '1–4',
#  '2–1',
#  '1–3',
#  '1–2',
#  '2–1',
#  '0–1',
#  '0–1',
#  '0–0',
#  '2–1',
#  '3–0',
#  '2–5',
#  '1–2',
#  '0–3',
#  '0–0',
#  '2–1',
#  '0–0',
#  '1–0',
#  '1–0',
#  '2–3',
#  '3–1',
#  '4–0',
#  '1–2',
#  '2–2',
#  '2–2',
#  '0–1',
#  '2–1',
#  '2–1',
#  '1–1',
#  '1–0',
#  '2–4',
#  '0–1',
#  '1–1',
#  '1–1 (a.e.t.)',
#  '2–0',
#  '2–1',
#  '1–1 (a.e.t.)',
#  '2–0',
#  '2–1 (a.e.t.)',
#  '1–0 (a.e.t.)',
#  '2–1 (a.e.t.)',
#  '0–1',
#  '2–1',
#  '1–0',
#  '0–0 (a.e.t.)',
#  '1–7',
#  '0–0 (a.e.t.)',
#  '0–3',
#  '1–0 (a.e.t.)']

# %%
# PARA MANTENER EL ORDEN CREARE UN DICTIONARIO
dict_football = {'home':home,'score':score,'away':away}

df_football = pd.DataFrame(dict_football)

# %%
df_football
# Out:
#             home         score          away
# 0        Brazil            3–1       Croatia
# 1        Mexico            1–0      Cameroon
# 2        Brazil            0–0        Mexico
# 3      Cameroon            0–4       Croatia
# 4      Cameroon            1–4        Brazil
# ..           ...           ...           ...
# 59  Netherlands   0–0 (a.e.t.)    Costa Rica
# 60       Brazil            1–7       Germany
# 61  Netherlands   0–0 (a.e.t.)     Argentina
# 62       Brazil            0–3   Netherlands
# 63      Germany   1–0 (a.e.t.)     Argentina
#
# [64 rows x 3 columns]

# %%
df_football['year']='2014'

# %%
df_football
# Out:
#             home         score          away  year
# 0        Brazil            3–1       Croatia  2014
# 1        Mexico            1–0      Cameroon  2014
# 2        Brazil            0–0        Mexico  2014
# 3      Cameroon            0–4       Croatia  2014
# 4      Cameroon            1–4        Brazil  2014
# ..           ...           ...           ...   ...
# 59  Netherlands   0–0 (a.e.t.)    Costa Rica  2014
# 60       Brazil            1–7       Germany  2014
# 61  Netherlands   0–0 (a.e.t.)     Argentina  2014
# 62       Brazil            0–3   Netherlands  2014
# 63      Germany   1–0 (a.e.t.)     Argentina  2014
#
# [64 rows x 4 columns]

# %%
df_football.describe()
# Out:
#            home score         away  year
# count        64    64           64    64
# unique       32    25           32     1
# top     Brazil    2–1   Costa Rica  2014
# freq          6    10            3    64

# %%
df_football.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   home    64 non-null     object
#  1   score   64 non-null     object
#  2   away    64 non-null     object
#  3   year    64 non-null     object
# dtypes: object(4)
# memory usage: 2.1+ KB

# %%
print(df_football)
# Out:
#             home         score          away  year
# 0        Brazil            3–1       Croatia  2014
# 1        Mexico            1–0      Cameroon  2014
# 2        Brazil            0–0        Mexico  2014
# 3      Cameroon            0–4       Croatia  2014
# 4      Cameroon            1–4        Brazil  2014
# ..           ...           ...           ...   ...
# 59  Netherlands   0–0 (a.e.t.)    Costa Rica  2014
# 60       Brazil            1–7       Germany  2014
# 61  Netherlands   0–0 (a.e.t.)     Argentina  2014
# 62       Brazil            0–3   Netherlands  2014
# 63      Germany   1–0 (a.e.t.)     Argentina  2014
#
# [64 rows x 4 columns]

# %%
display(df_football)
# Out:
#             home         score          away  year
# 0        Brazil            3–1       Croatia  2014
# 1        Mexico            1–0      Cameroon  2014
# 2        Brazil            0–0        Mexico  2014
# 3      Cameroon            0–4       Croatia  2014
# 4      Cameroon            1–4        Brazil  2014
# ..           ...           ...           ...   ...
# 59  Netherlands   0–0 (a.e.t.)    Costa Rica  2014
# 60       Brazil            1–7       Germany  2014
# 61  Netherlands   0–0 (a.e.t.)     Argentina  2014
# 62       Brazil            0–3   Netherlands  2014
# 63      Germany   1–0 (a.e.t.)     Argentina  2014
#
# [64 rows x 4 columns]

# %% [markdown]
# Ahora como paso siguiente necesitamos hacer la extraccion de los resultados de los mundiales desde el año 1930 hasta el 2018

# %% [markdown]
# Y luego como paso final el cronograma o fixture del 2022

# %% [markdown]
# Para poder simplificar esta funcion necesito crear una funcion, a esta funcion le llamaremos obtener partido o get_matches.

# %% [markdown]
# # **METODO DE EXTRACCION DE DATOS**

# %%
years,len(years)
# Out:
# ([1930,
#   1934,
#   1938,
#   1942,
#   1946,
#   1950,
#   1954,
#   1958,
#   1962,
#   1966,
#   1970,
#   1974,
#   1978,
#   1982,
#   1986,
#   1990,
#   1994,
#   1998,
#   2002,
#   2006,
#   2010,
#   2014,
#   2018],
#  23)

# %%
def get_matches(year):
    web=f'https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup'# cadena f para tener variables dentro de la cadena de texto entre corchetes
    response =requests.get(web)
    content=response.text
    soup =BeautifulSoup(content,'lxml')
    matches= soup.find_all('div',class_='footballbox')
    home= []
    score=[]
    away= []
    for match in matches:
      home.append(match.find('th',class_='fhome').get_text())
      score.append(match.find('th',class_='fscore').get_text())
      away.append(match.find('th',class_='faway').get_text())
    dict_football = {'home':home,'score':score,'away':away}
    df_football= pd.DataFrame(dict_football)
    df_football['year']= year
    return df_football

# %%
print(get_matches(2014))
# Out:
#             home         score          away  year
# 0        Brazil            3–1       Croatia  2014
# 1        Mexico            1–0      Cameroon  2014
# 2        Brazil            0–0        Mexico  2014
# 3      Cameroon            0–4       Croatia  2014
# 4      Cameroon            1–4        Brazil  2014
# ..           ...           ...           ...   ...
# 59  Netherlands   0–0 (a.e.t.)    Costa Rica  2014
# 60       Brazil            1–7       Germany  2014
# 61  Netherlands   0–0 (a.e.t.)     Argentina  2014
# 62       Brazil            0–3   Netherlands  2014
# 63      Germany   1–0 (a.e.t.)     Argentina  2014
#
# [64 rows x 4 columns]

# %%
print(get_matches(2018))
# Out:
#         home         score           away  year
# 0    Russia            5–0   Saudi Arabia  2018
# 1     Egypt            0–1        Uruguay  2018
# 2    Russia            3–1          Egypt  2018
# 3   Uruguay            1–0   Saudi Arabia  2018
# 4   Uruguay            3–0         Russia  2018
# ..       ...           ...            ...   ...
# 59   Russia   2–2 (a.e.t.)        Croatia  2018
# 60   France            1–0        Belgium  2018
# 61  Croatia   2–1 (a.e.t.)        England  2018
# 62  Belgium            2–0        England  2018
# 63   France            4–2        Croatia  2018
#
# [64 rows x 4 columns]

# %%
print(get_matches(2010))
# Out:
#              home         score          away  year
# 0   South Africa            1–1        Mexico  2010
# 1        Uruguay            0–0        France  2010
# 2   South Africa            0–3       Uruguay  2010
# 3         France            0–2        Mexico  2010
# 4         Mexico            0–1       Uruguay  2010
# ..            ...           ...           ...   ...
# 59      Paraguay            0–1         Spain  2010
# 60       Uruguay            2–3   Netherlands  2010
# 61       Germany            0–1         Spain  2010
# 62       Uruguay            2–3       Germany  2010
# 63   Netherlands   0–1 (a.e.t.)         Spain  2010
#
# [64 rows x 4 columns]

# %%
print(get_matches(2006))
# Out:
#          home         score         away  year
# 0    Germany            4–2   Costa Rica  2006
# 1     Poland            0–2      Ecuador  2006
# 2    Germany            1–0       Poland  2006
# 3    Ecuador            3–0   Costa Rica  2006
# 4    Ecuador            0–3      Germany  2006
# ..        ...           ...          ...   ...
# 59    Brazil            0–1       France  2006
# 60   Germany   0–2 (a.e.t.)        Italy  2006
# 61  Portugal            0–1       France  2006
# 62   Germany            3–1     Portugal  2006
# 63     Italy   1–1 (a.e.t.)       France  2006
#
# [64 rows x 4 columns]

# %%
print(get_matches(2002))
# Out:
#             home              score          away  year
# 0        France                 0–1       Senegal  2002
# 1       Uruguay                 1–2       Denmark  2002
# 2       Denmark                 1–1       Senegal  2002
# 3        France                 0–0       Uruguay  2002
# 4       Denmark                 2–0        France  2002
# ..           ...                ...           ...   ...
# 59      Senegal   0–1 (a.e.t./g.g.)        Turkey  2002
# 60      Germany                 1–0   South Korea  2002
# 61       Brazil                 1–0        Turkey  2002
# 62  South Korea                 2–3        Turkey  2002
# 63      Germany                 0–2        Brazil  2002
#
# [64 rows x 4 columns]

# %%
print(get_matches(1982))
# Out:
#                home         score               away  year
# 0            Italy            0–0             Poland  1982
# 1             Peru            0–0           Cameroon  1982
# 2            Italy            1–1               Peru  1982
# 3           Poland            0–0           Cameroon  1982
# 4           Poland            5–1               Peru  1982
# 5            Italy            1–1           Cameroon  1982
# 6     West Germany            1–2            Algeria  1982
# 7            Chile            0–1            Austria  1982
# 8     West Germany            4–1              Chile  1982
# 9          Algeria            0–2            Austria  1982
# 10         Algeria            3–2              Chile  1982
# 11    West Germany            1–0            Austria  1982
# 12       Argentina            0–1            Belgium  1982
# 13         Hungary           10–1        El Salvador  1982
# 14       Argentina            4–1            Hungary  1982
# ...

# %%
years
# Out:
# [1930,
#  1934,
#  1938,
#  1942,
#  1946,
#  1950,
#  1954,
#  1958,
#  1962,
#  1966,
#  1970,
#  1974,
#  1978,
#  1982,
#  1986,
#  1990,
#  1994,
#  1998,
#  2002,
#  2006,
#  2010,
#  2014,
#  2018]

# %%
fifa = [get_matches(year) for year in years]

# %%
fifa[6]
# Out:
#              home         score             away  year
# 0         Brazil            5–0           Mexico  1954
# 1     Yugoslavia            1–0           France  1954
# 2         Brazil   1–1 (a.e.t.)       Yugoslavia  1954
# 3         France            3–2           Mexico  1954
# 4   West Germany            4–1           Turkey  1954
# 5        Hungary            9–0      South Korea  1954
# 6        Hungary            8–3     West Germany  1954
# 7         Turkey            7–0      South Korea  1954
# 8   West Germany            7–2           Turkey  1954
# 9        Uruguay            2–0   Czechoslovakia  1954
# 10       Austria            1–0         Scotland  1954
# 11       Uruguay            7–0         Scotland  1954
# 12       Austria            5–0   Czechoslovakia  1954
# 13   Switzerland            2–1            Italy  1954
# 14       England   4–4 (a.e.t.)          Belgium  1954
# 15         Italy            4–1          Belgium  1954
# ...

# %%
df_fifa= pd.concat(fifa,ignore_index=True)

# %%
df_fifa
# Out:
#            home         score      away  year
# 0       France            4–1    Mexico  1930
# 1    Argentina            1–0    France  1930
# 2        Chile            3–0    Mexico  1930
# 3        Chile            1–0    France  1930
# 4    Argentina            6–3    Mexico  1930
# ..          ...           ...       ...   ...
# 860     Russia   2–2 (a.e.t.)   Croatia  2018
# 861     France            1–0   Belgium  2018
# 862    Croatia   2–1 (a.e.t.)   England  2018
# 863    Belgium            2–0   England  2018
# 864     France            4–2   Croatia  2018
#
# [865 rows x 4 columns]

# %%
df_fifa.to_csv("fifa_world_cup_matches.csv")

# %%
## EXTRACTION DE FIXTURE

# %% [markdown]
# Al iniciar el mundial, la pagina de wikipedia  va a actualizar los resultados finales de los partidos del mundial 2022. En caso deseen extraer el fixture del 2022 usar esta pagina:

# %%
link_web= 'https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup'

# %%
def get_fixture(year):
    web=f'https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/{year}_FIFA_World_Cup'# cadena f para tener variables dentro de la cadena de texto entre corchetes
    response =requests.get(web)
    content=response.text
    soup =BeautifulSoup(content,'lxml')
    matches= soup.find_all('div',class_='footballbox')
    home= []
    score=[]
    away= []
    for match in matches:
      home.append(match.find('th',class_='fhome').get_text())
      score.append(match.find('th',class_='fscore').get_text())
      away.append(match.find('th',class_='faway').get_text())
    dict_football = {'home':home,'score':score,'away':away}
    df_football= pd.DataFrame(dict_football)
    df_football['year']= year
    return df_football

# %%
df_fixture = get_fixture(2022)

# %%
df_fixture
# Out:
#                 home     score              away  year
# 0             Qatar    Match 1           Ecuador  2022
# 1           Senegal    Match 2       Netherlands  2022
# 2             Qatar   Match 18           Senegal  2022
# 3       Netherlands   Match 19           Ecuador  2022
# 4           Ecuador   Match 35           Senegal  2022
# ..               ...       ...               ...   ...
# 59  Winners Match 51  Match 59  Winners Match 52  2022
# 60  Winners Match 57  Match 61  Winners Match 58  2022
# 61  Winners Match 59  Match 62  Winners Match 60  2022
# 62   Losers Match 61  Match 63   Losers Match 62  2022
# 63  Winners Match 61  Match 64  Winners Match 62  2022
#
# [64 rows x 4 columns]

# %%
df_fixture.to_csv('fifa_worlcup_fixture.csv',index=False)

# %% [markdown]
# # 3. PREPARACION DE DATOS Y EDA
#
# Después de recopilar los datos, entra en juego la preparación de los datos. Implica limpiar y organizar los datos, lo que se sabe que ocupa más del 80% del trabajo de los científicos de datos. Los datos del mundo real están sin procesar y pueden estar llenos de duplicados, valores faltantes e información incorrecta. Por lo tanto, es necesario limpiar los datos.
#
# Una vez que se han organizado los datos, extraemos la información contenida en los datos y resumimos sus principales características a través del análisis exploratorio de datos. EDA es una etapa importante para un proyecto de ciencia de datos bien definido. Se realiza antes de la fase de modelado estadístico o de aprendizaje automático.
#
# ***¡Basta de teoría, comencemos con la parte práctica!***

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **DATA CLEANING**

# %%
df_fixture = pd.read_csv('/content/fifa_worlcup_fixture.csv')
df_historical_data = pd.read_csv('/content/fifa_world_cup_matches.csv')

# %%
df_historical_data = pd.read_csv('/content/fifa_world_cup_matches.csv')

# %%
df_fixture
# Out:
#                 home     score              away  year
# 0             Qatar    Match 1           Ecuador  2022
# 1           Senegal    Match 2       Netherlands  2022
# 2             Qatar   Match 18           Senegal  2022
# 3       Netherlands   Match 19           Ecuador  2022
# 4           Ecuador   Match 35           Senegal  2022
# ..               ...       ...               ...   ...
# 59  Winners Match 51  Match 59  Winners Match 52  2022
# 60  Winners Match 57  Match 61  Winners Match 58  2022
# 61  Winners Match 59  Match 62  Winners Match 60  2022
# 62   Losers Match 61  Match 63   Losers Match 62  2022
# 63  Winners Match 61  Match 64  Winners Match 62  2022
#
# [64 rows x 4 columns]

# %%
df_historical_data
# Out:
#      Unnamed: 0        home         score      away  year
# 0             0     France            4–1    Mexico  1930
# 1             1  Argentina            1–0    France  1930
# 2             2      Chile            3–0    Mexico  1930
# 3             3      Chile            1–0    France  1930
# 4             4  Argentina            6–3    Mexico  1930
# ..          ...         ...           ...       ...   ...
# 860         860     Russia   2–2 (a.e.t.)   Croatia  2018
# 861         861     France            1–0   Belgium  2018
# 862         862    Croatia   2–1 (a.e.t.)   England  2018
# 863         863    Belgium            2–0   England  2018
# 864         864     France            4–2   Croatia  2018
#
# [865 rows x 5 columns]

# %% [markdown]
# ## CLEANING DATA_FIXTURE

# %%
df_fixture['home']
# Out:
# 0               Qatar
# 1             Senegal
# 2               Qatar
# 3         Netherlands
# 4             Ecuador
#             ...
# 59    Winners Match 51
# 60    Winners Match 57
# 61    Winners Match 59
# 62     Losers Match 61
# 63    Winners Match 61
# Name: home, Length: 64, dtype: object

# %%
df_fixture['home']=df_fixture['home'].str.strip()

# %%
df_fixture['home']
# Out:
# 0                Qatar
# 1              Senegal
# 2                Qatar
# 3          Netherlands
# 4              Ecuador
#             ...
# 59    Winners Match 51
# 60    Winners Match 57
# 61    Winners Match 59
# 62     Losers Match 61
# 63    Winners Match 61
# Name: home, Length: 64, dtype: object

# %%
df_fixture['away']
# Out:
# 0              Ecuador
# 1          Netherlands
# 2              Senegal
# 3              Ecuador
# 4              Senegal
#             ...
# 59    Winners Match 52
# 60    Winners Match 58
# 61    Winners Match 60
# 62     Losers Match 62
# 63    Winners Match 62
# Name: away, Length: 64, dtype: object

# %%
df_fixture['away']=df_fixture['away'].str.strip()

# %%
df_fixture['away']
# Out:
# 0              Ecuador
# 1          Netherlands
# 2              Senegal
# 3              Ecuador
# 4              Senegal
#             ...
# 59    Winners Match 52
# 60    Winners Match 58
# 61    Winners Match 60
# 62     Losers Match 62
# 63    Winners Match 62
# Name: away, Length: 64, dtype: object

# %%
df_fixture[df_fixture['home'].isnull()]
# Out:
# Empty DataFrame
# Columns: [home, score, away, year]
# Index: []

# %%
df_fixture.to_csv('clean_fifa_worldcup_fixture.csv')

# %%
df_fixture
# Out:
#                 home     score              away  year
# 0              Qatar   Match 1           Ecuador  2022
# 1            Senegal   Match 2       Netherlands  2022
# 2              Qatar  Match 18           Senegal  2022
# 3        Netherlands  Match 19           Ecuador  2022
# 4            Ecuador  Match 35           Senegal  2022
# ..               ...       ...               ...   ...
# 59  Winners Match 51  Match 59  Winners Match 52  2022
# 60  Winners Match 57  Match 61  Winners Match 58  2022
# 61  Winners Match 59  Match 62  Winners Match 60  2022
# 62   Losers Match 61  Match 63   Losers Match 62  2022
# 63  Winners Match 61  Match 64  Winners Match 62  2022
#
# [64 rows x 4 columns]

# %% [markdown]
# ## **CLEANING  HISTORICAL DATA**

# %%
#df_historical_data[df_historical_data['home'].isnull()]
df_historical_data.drop_duplicates(inplace=True)

# %%
df_historical_data
# Out:
#      Unnamed: 0        home         score      away  year
# 0             0     France            4–1    Mexico  1930
# 1             1  Argentina            1–0    France  1930
# 2             2      Chile            3–0    Mexico  1930
# 3             3      Chile            1–0    France  1930
# 4             4  Argentina            6–3    Mexico  1930
# ..          ...         ...           ...       ...   ...
# 860         860     Russia   2–2 (a.e.t.)   Croatia  2018
# 861         861     France            1–0   Belgium  2018
# 862         862    Croatia   2–1 (a.e.t.)   England  2018
# 863         863    Belgium            2–0   England  2018
# 864         864     France            4–2   Croatia  2018
#
# [865 rows x 5 columns]

# %%
df_historical_data.sort_values('year',inplace=True)
df_historical_data
# Out:
#      Unnamed: 0        home score            away  year
# 0             0     France    4–1          Mexico  1930
# 17           17    Uruguay    4–2       Argentina  1930
# 16           16    Uruguay    6–1      Yugoslavia  1930
# 15           15  Argentina    6–1   United States  1930
# 14           14   Paraguay    1–0         Belgium  1930
# ..          ...         ...   ...             ...   ...
# 827         827     Brazil    2–0      Costa Rica  2018
# 828         828     Serbia    1–2     Switzerland  2018
# 829         829     Serbia    0–2          Brazil  2018
# 831         831    Germany    0–1          Mexico  2018
# 864         864     France    4–2         Croatia  2018
#
# [865 rows x 5 columns]

# %%
delete_index = df_historical_data[df_historical_data['home'].str.contains('Sweden') & df_historical_data['away'].str.contains('Austria')].index
df_historical_data.drop(index=delete_index,inplace=True)

# %%
df_historical_data
# Out:
#      Unnamed: 0        home score            away  year
# 0             0     France    4–1          Mexico  1930
# 17           17    Uruguay    4–2       Argentina  1930
# 16           16    Uruguay    6–1      Yugoslavia  1930
# 15           15  Argentina    6–1   United States  1930
# 14           14   Paraguay    1–0         Belgium  1930
# ..          ...         ...   ...             ...   ...
# 827         827     Brazil    2–0      Costa Rica  2018
# 828         828     Serbia    1–2     Switzerland  2018
# 829         829     Serbia    0–2          Brazil  2018
# 831         831    Germany    0–1          Mexico  2018
# 864         864     France    4–2         Croatia  2018
#
# [864 rows x 5 columns]

# %%
df_historical_data['score']
# Out:
# 0      4–1
# 17     4–2
# 16     6–1
# 15     6–1
# 14     1–0
#       ...
# 827    2–0
# 828    1–2
# 829    0–2
# 831    0–1
# 864    4–2
# Name: score, Length: 864, dtype: object

# %%
df_historical_data['score']=df_historical_data['score'].str.replace('^\d–]','',regex=True)

# %%
df_historical_data
# Out:
#      Unnamed: 0        home score            away  year
# 0             0     France    4–1          Mexico  1930
# 17           17    Uruguay    4–2       Argentina  1930
# 16           16    Uruguay    6–1      Yugoslavia  1930
# 15           15  Argentina    6–1   United States  1930
# 14           14   Paraguay    1–0         Belgium  1930
# ..          ...         ...   ...             ...   ...
# 827         827     Brazil    2–0      Costa Rica  2018
# 828         828     Serbia    1–2     Switzerland  2018
# 829         829     Serbia    0–2          Brazil  2018
# 831         831    Germany    0–1          Mexico  2018
# 864         864     France    4–2         Croatia  2018
#
# [864 rows x 5 columns]

# %%
df_historical_data['home']=df_historical_data['home'].str.strip()
df_historical_data['away']=df_historical_data['away'].str.strip()

# %%
df_historical_data
# Out:
#      Unnamed: 0       home score           away  year
# 0             0     France   4–1         Mexico  1930
# 17           17    Uruguay   4–2      Argentina  1930
# 16           16    Uruguay   6–1     Yugoslavia  1930
# 15           15  Argentina   6–1  United States  1930
# 14           14   Paraguay   1–0        Belgium  1930
# ..          ...        ...   ...            ...   ...
# 827         827     Brazil   2–0     Costa Rica  2018
# 828         828     Serbia   1–2    Switzerland  2018
# 829         829     Serbia   0–2         Brazil  2018
# 831         831    Germany   0–1         Mexico  2018
# 864         864     France   4–2        Croatia  2018
#
# [864 rows x 5 columns]

# %%
df_historical_data[['HomeGoals','AwayGoals']] = df_historical_data['score'].str.split('–',expand=True)

# %%
df_historical_data
# Out:
#      Unnamed: 0       home score           away  year HomeGoals AwayGoals
# 0             0     France   4–1         Mexico  1930         4         1
# 17           17    Uruguay   4–2      Argentina  1930         4         2
# 16           16    Uruguay   6–1     Yugoslavia  1930         6         1
# 15           15  Argentina   6–1  United States  1930         6         1
# 14           14   Paraguay   1–0        Belgium  1930         1         0
# ..          ...        ...   ...            ...   ...       ...       ...
# 827         827     Brazil   2–0     Costa Rica  2018         2         0
# 828         828     Serbia   1–2    Switzerland  2018         1         2
# 829         829     Serbia   0–2         Brazil  2018         0         2
# 831         831    Germany   0–1         Mexico  2018         0         1
# 864         864     France   4–2        Croatia  2018         4         2
#
# [864 rows x 7 columns]

# %%
df_historical_data.drop('score',axis=1,inplace=True)

# %%
df_historical_data
# Out:
#      Unnamed: 0       home           away  year HomeGoals AwayGoals
# 0             0     France         Mexico  1930         4         1
# 17           17    Uruguay      Argentina  1930         4         2
# 16           16    Uruguay     Yugoslavia  1930         6         1
# 15           15  Argentina  United States  1930         6         1
# 14           14   Paraguay        Belgium  1930         1         0
# ..          ...        ...            ...   ...       ...       ...
# 827         827     Brazil     Costa Rica  2018         2         0
# 828         828     Serbia    Switzerland  2018         1         2
# 829         829     Serbia         Brazil  2018         0         2
# 831         831    Germany         Mexico  2018         0         1
# 864         864     France        Croatia  2018         4         2
#
# [864 rows x 6 columns]

# %%
df_historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 864 entries, 0 to 864
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  864 non-null    int64
#  1   home        864 non-null    object
#  2   away        864 non-null    object
#  3   year        864 non-null    int64
#  4   HomeGoals   864 non-null    object
#  5   AwayGoals   864 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 47.2+ KB

# %%
# renombre comlumnas y tipos de datos
df_historical_data.rename(columns={'home':'HomeTeam','away':'AwayTeam','year':'Year'},inplace=True)

# %%
df_historical_data
# Out:
#      Unnamed: 0   HomeTeam       AwayTeam  Year HomeGoals AwayGoals
# 0             0     France         Mexico  1930         4         1
# 17           17    Uruguay      Argentina  1930         4         2
# 16           16    Uruguay     Yugoslavia  1930         6         1
# 15           15  Argentina  United States  1930         6         1
# 14           14   Paraguay        Belgium  1930         1         0
# ..          ...        ...            ...   ...       ...       ...
# 827         827     Brazil     Costa Rica  2018         2         0
# 828         828     Serbia    Switzerland  2018         1         2
# 829         829     Serbia         Brazil  2018         0         2
# 831         831    Germany         Mexico  2018         0         1
# 864         864     France        Croatia  2018         4         2
#
# [864 rows x 6 columns]

# %%
df_historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 864 entries, 0 to 864
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  864 non-null    int64
#  1   HomeTeam    864 non-null    object
#  2   AwayTeam    864 non-null    object
#  3   Year        864 non-null    int64
#  4   HomeGoals   864 non-null    object
#  5   AwayGoals   864 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 47.2+ KB

# %%
# Out:
# 0      1
# 17     2
# 16     1
# 15     1
# 14     0
#       ..
# 827    0
# 828    2
# 829    2
# 831    1
# 864    2
# Name: AwayGoals, Length: 864, dtype: object

# %%
rows_with_aet = df_historical_data[df_historical_data['AwayGoals'].str.contains('1 \(a\.e\.t\.\)')]
rows_with_aet
# Out:
#      Unnamed: 0          HomeTeam             AwayTeam  Year HomeGoals  \
# 27           27             Italy                Spain  1934         1
# 34           34             Italy       Czechoslovakia  1934         2
# 48           48            Brazil       Czechoslovakia  1938         1
# 40           40             Italy               Norway  1938         2
# 35           35       Switzerland              Germany  1938         1
# 78           78            Brazil           Yugoslavia  1954         1
# 108         108  Northern Ireland       Czechoslovakia  1958         2
# 225         225      Soviet Union              Uruguay  1970         0
# 308         308         Argentina          Netherlands  1978         3
# 405         405            Brazil               France  1986         1
# 408         408             Spain              Belgium  1986         1
# 426         426      West Germany              England  1990         1
# ...

# %%
rows_with_aet['AwayGoals'].str.extract(r'(\d+)')
# Out:
#      0
# 27   1
# 34   1
# 48   1
# 40   1
# 35   1
# 78   1
# 108  1
# 225  1
# 308  1
# 405  1
# 408  1
# 426  1
# 425  1
# 413  1
# 472  1
# 541  1
# 596  1
# 658  1
# 672  1
# 665  1
# 730  1
# 736  1
# 788  1
# 790  1
# 792  1
# 785  1
# 862  1
# 851  1
# 852  1
# 856  1

# %%
df_historical_data['AwayGoals']= df_historical_data['AwayGoals'].str.extract(r'(\d+)')

# %%
df_historical_data = df_historical_data.astype({'HomeGoals':int, 'AwayGoals':int,'Year':int})

# %%
df_historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 864 entries, 0 to 864
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  864 non-null    int64
#  1   HomeTeam    864 non-null    object
#  2   AwayTeam    864 non-null    object
#  3   Year        864 non-null    int64
#  4   HomeGoals   864 non-null    int64
#  5   AwayGoals   864 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 47.2+ KB

# %%
df_historical_data['TotalGoals']= df_historical_data['HomeGoals']+df_historical_data['AwayGoals']

# %%
df_historical_data
# Out:
#      Unnamed: 0   HomeTeam       AwayTeam  Year  HomeGoals  AwayGoals  \
# 0             0     France         Mexico  1930          4          1
# 17           17    Uruguay      Argentina  1930          4          2
# 16           16    Uruguay     Yugoslavia  1930          6          1
# 15           15  Argentina  United States  1930          6          1
# 14           14   Paraguay        Belgium  1930          1          0
# ..          ...        ...            ...   ...        ...        ...
# 827         827     Brazil     Costa Rica  2018          2          0
# 828         828     Serbia    Switzerland  2018          1          2
# 829         829     Serbia         Brazil  2018          0          2
# 831         831    Germany         Mexico  2018          0          1
# 864         864     France        Croatia  2018          4          2
#
#      TotalGoals
# 0             5
# 17            6
# 16            7
# 15            7
# 14            1
# ..          ...
# ...

# %%
df_historical_data.to_csv('clean_fifa_worldcup_matches.csv',index=False)

# %% [markdown]
# ## **CONTINUACION 24/04/2024 C4 4TA SESION**

# %% [markdown]
# # **RECOLECCION DE TABLAS FASE DE GRUPOS**

# %%
link ='https://web.archive.org/web/20221115040351/https://en.wikipedia.org/wiki/2022_FIFA_World_Cup'

# %%
import pandas as pd

# %%
# extraccion de las tables del sitio web
all_tables= pd.read_html(link)
print(all_tables)
# Out:
# [      0     1     2
# 0   Oct   NOV   Dec
# 1   NaN    15   NaN
# 2  2021  2022  2023,   2022 كأس العالم لكرة القدم Kaʾs al-ʿālam li-kurat al-qadam 2022 Qatar 2022 2022 قطر  \
# 0                                         Now is All
# 1                                 Tournament details
# 2                                       Host country
# 3                                              Dates
# 4                                              Teams
# 5                                           Venue(s)
# 6                                      ← 2018 2026 →
#
#   2022 كأس العالم لكرة القدم Kaʾs al-ʿālam li-kurat al-qadam 2022 Qatar 2022 2022 قطر.1
# 0                                         Now is All
# 1                                 Tournament details
# 2                                              Qatar
# 3                          20 November – 18 December
# 4                         32 (from 5 confederations)
# 5                               8 (in 5 host cities)
# ...

# %%
print(all_tables[12])
# Out:
#    Pos  \
# 0    1
# 1    2
# 2    3
# 3    4
#
#   Team.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte  \
# 0                                          Qatar (H)
# 1                                            Ecuador
# ...

# %%
print(all_tables[12])
# Out:
#    Pos  \
# 0    1
# 1    2
# 2    3
# 3    4
#
#   Team.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte  \
# 0                                          Qatar (H)
# 1                                            Ecuador
# ...

# %%
print(all_tables[19])
# Out:
#    Pos        Teamvte  Pld  W  D  L  GF  GA  GD  Pts  \
# 0    1        England    0  0  0  0   0   0   0    0
# 1    2           Iran    0  0  0  0   0   0   0    0
# 2    3  United States    0  0  0  0   0   0   0    0
# 3    4          Wales    0  0  0  0   0   0   0    0
#
#                Qualification
# 0  Advance to knockout stage
# 1  Advance to knockout stage
# 2                        NaN
# 3                        NaN

# %%
print(all_tables[26])
# Out:
#    Pos       Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1     Argentina    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2  Saudi Arabia    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3        Mexico    0  0  0  0   0   0   0    0                        NaN
# 3    4        Poland    0  0  0  0   0   0   0    0                        NaN

# %%
print(all_tables[61])
# Out:
#    Pos      Teamvte  Pld  W  D  L  GF  GA  GD  Pts              Qualification
# 0    1     Portugal    0  0  0  0   0   0   0    0  Advance to knockout stage
# 1    2        Ghana    0  0  0  0   0   0   0    0  Advance to knockout stage
# 2    3      Uruguay    0  0  0  0   0   0   0    0                        NaN
# 3    4  South Korea    0  0  0  0   0   0   0    0                        NaN

# %%
for i in range(12,68,7):
  df =all_tables[i]
  df.rename(columns={df.columns[1]:'Team'}, inplace = True)
  df.pop('Qualification')
  print(df)
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0
# 1    2      Ecuador    0  0  0  0   0   0   0    0
# 2    3      Senegal    0  0  0  0   0   0   0    0
# 3    4  Netherlands    0  0  0  0   0   0   0    0
#    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1        England    0  0  0  0   0   0   0    0
# 1    2           Iran    0  0  0  0   0   0   0    0
# 2    3  United States    0  0  0  0   0   0   0    0
# 3    4          Wales    0  0  0  0   0   0   0    0
#    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     Argentina    0  0  0  0   0   0   0    0
# 1    2  Saudi Arabia    0  0  0  0   0   0   0    0
# 2    3        Mexico    0  0  0  0   0   0   0    0
# 3    4        Poland    0  0  0  0   0   0   0    0
#    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1     France    0  0  0  0   0   0   0    0
# 1    2  Australia    0  0  0  0   0   0   0    0
# ...

# %%
from string import ascii_uppercase as  alphabet

# %%
print(alphabet)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
all_tables= pd.read_html(link)
dict_table= {}
for letter,i in zip(alphabet,range(12,68,7)):
  df=all_tables[i]
  df.rename(columns={df.columns[1]:'Team'}, inplace = True)
  df.pop('Qualification')
  dict_table[f'Group {letter}']= df

# %%
dict_table
# Out:
# {'Group A':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1    Qatar (H)    0  0  0  0   0   0   0    0
#  1    2      Ecuador    0  0  0  0   0   0   0    0
#  2    3      Senegal    0  0  0  0   0   0   0    0
#  3    4  Netherlands    0  0  0  0   0   0   0    0,
#  'Group B':    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1        England    0  0  0  0   0   0   0    0
#  1    2           Iran    0  0  0  0   0   0   0    0
#  2    3  United States    0  0  0  0   0   0   0    0
#  3    4          Wales    0  0  0  0   0   0   0    0,
#  'Group C':    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     Argentina    0  0  0  0   0   0   0    0
#  1    2  Saudi Arabia    0  0  0  0   0   0   0    0
#  2    3        Mexico    0  0  0  0   0   0   0    0
#  3    4        Poland    0  0  0  0   0   0   0    0,
#  'Group D':    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     France    0  0  0  0   0   0   0    0
# ...

# %%
dict_table['Group A']
# Out:
#    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
# 0    1    Qatar (H)    0  0  0  0   0   0   0    0
# 1    2      Ecuador    0  0  0  0   0   0   0    0
# 2    3      Senegal    0  0  0  0   0   0   0    0
# 3    4  Netherlands    0  0  0  0   0   0   0    0

# %%
dict_table.keys()
# Out:
# dict_keys(['Group A', 'Group B', 'Group C', 'Group D', 'Group E', 'Group F', 'Group G', 'Group H'])

# %%
# cargar el dictionario
import pickle
with open('dict_table','wb') as output:
  pickle.dump(dict_table,output)

# %%
dict_table_load= pickle.load(open('/content/dict_table','rb'))

# %%
dict_table_load
# Out:
# {'Group A':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1    Qatar (H)    0  0  0  0   0   0   0    0
#  1    2      Ecuador    0  0  0  0   0   0   0    0
#  2    3      Senegal    0  0  0  0   0   0   0    0
#  3    4  Netherlands    0  0  0  0   0   0   0    0,
#  'Group B':    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1        England    0  0  0  0   0   0   0    0
#  1    2           Iran    0  0  0  0   0   0   0    0
#  2    3  United States    0  0  0  0   0   0   0    0
#  3    4          Wales    0  0  0  0   0   0   0    0,
#  'Group C':    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     Argentina    0  0  0  0   0   0   0    0
#  1    2  Saudi Arabia    0  0  0  0   0   0   0    0
#  2    3        Mexico    0  0  0  0   0   0   0    0
#  3    4        Poland    0  0  0  0   0   0   0    0,
#  'Group D':    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     France    0  0  0  0   0   0   0    0
# ...

# %% [markdown]
#  # 3. FEATURE ENGINEERING

# %% [markdown]
# El diagrama de dispersión muestra que no hay tendencias en los datos de Burn Rate vs Days Spent. Por lo tanto, eliminamos los días invertidos, ya que no tienen importancia en los datos.

# %% [markdown]
# # 4. **CONSTRUCCION DEL MODELO Y EVALUACION**

# %%
df_historical_data = pd.read_csv('/content/clean_fifa_worldcup_matches.csv')
df_fixture         = pd.read_csv('/content/clean_fifa_worldcup_fixture.csv')
dict_table         = pickle.load(open('dict_table','rb'))

# %%
df_historical_data
# Out:
#      Unnamed: 0   HomeTeam       AwayTeam  Year  HomeGoals  AwayGoals  \
# 0             0     France         Mexico  1930          4          1
# 1            17    Uruguay      Argentina  1930          4          2
# 2            16    Uruguay     Yugoslavia  1930          6          1
# 3            15  Argentina  United States  1930          6          1
# 4            14   Paraguay        Belgium  1930          1          0
# ..          ...        ...            ...   ...        ...        ...
# 859         827     Brazil     Costa Rica  2018          2          0
# 860         828     Serbia    Switzerland  2018          1          2
# 861         829     Serbia         Brazil  2018          0          2
# 862         831    Germany         Mexico  2018          0          1
# 863         864     France        Croatia  2018          4          2
#
#      TotalGoals
# 0             5
# 1             6
# 2             7
# 3             7
# 4             1
# ..          ...
# ...

# %%
df_home =  df_historical_data[['HomeTeam','HomeGoals','AwayGoals']]
df_away =  df_historical_data[['AwayTeam','HomeGoals','AwayGoals']]

# %%
df_home
# Out:
#       HomeTeam  HomeGoals  AwayGoals
# 0       France          4          1
# 1      Uruguay          4          2
# 2      Uruguay          6          1
# 3    Argentina          6          1
# 4     Paraguay          1          0
# ..         ...        ...        ...
# 859     Brazil          2          0
# 860     Serbia          1          2
# 861     Serbia          0          2
# 862    Germany          0          1
# 863     France          4          2
#
# [864 rows x 3 columns]

# %%
df_away
# Out:
#           AwayTeam  HomeGoals  AwayGoals
# 0           Mexico          4          1
# 1        Argentina          4          2
# 2       Yugoslavia          6          1
# 3    United States          6          1
# 4          Belgium          1          0
# ..             ...        ...        ...
# 859     Costa Rica          2          0
# 860    Switzerland          1          2
# 861         Brazil          0          2
# 862         Mexico          0          1
# 863        Croatia          4          2
#
# [864 rows x 3 columns]

# %%
df_home = df_home.rename(columns={'HomeTeam':'Team','HomeGoals':'GoalsScored','AwayGoals':'GoalsConceded'})
df_away = df_away.rename(columns={'AwayTeam': 'Team','HomeGoals':'GoalsConceded','AwayGoals':'GoalsScored'})

# %%
df_home
# Out:
#           Team  GoalsScored  GoalsConceded
# 0       France            4              1
# 1      Uruguay            4              2
# 2      Uruguay            6              1
# 3    Argentina            6              1
# 4     Paraguay            1              0
# ..         ...          ...            ...
# 859     Brazil            2              0
# 860     Serbia            1              2
# 861     Serbia            0              2
# 862    Germany            0              1
# 863     France            4              2
#
# [864 rows x 3 columns]

# %%
df_away
# Out:
#               Team  GoalsConceded  GoalsScored
# 0           Mexico              4            1
# 1        Argentina              4            2
# 2       Yugoslavia              6            1
# 3    United States              6            1
# 4          Belgium              1            0
# ..             ...            ...          ...
# 859     Costa Rica              2            0
# 860    Switzerland              1            2
# 861         Brazil              0            2
# 862         Mexico              0            1
# 863        Croatia              4            2
#
# [864 rows x 3 columns]

# %%
df_team_strength = pd.concat([df_home,df_away],ignore_index=True).groupby(['Team']).mean()

# %%
df_team_strength
# Out:
#               GoalsScored  GoalsConceded
# Team
# Algeria          1.000000       1.461538
# Angola           0.333333       0.666667
# Argentina        1.717949       1.166667
# Australia        0.812500       1.937500
# Austria          1.576923       1.692308
# ...                   ...            ...
# Uruguay          1.603774       1.339623
# Wales            0.800000       0.800000
# West Germany     2.050847       1.254237
# Yugoslavia       1.633333       1.233333
# Zaire            0.000000       4.666667
#
# [84 rows x 2 columns]

# %%
df_team_strength.index
# Out:
# Index(['Algeria', 'Angola', 'Argentina', 'Australia', 'Austria', 'Belgium',
#        'Bolivia', 'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cameroon',
#        'Canada', 'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Czech Republic', 'Czechoslovakia', 'Denmark', 'Dutch East Indies',
#        'East Germany', 'Ecuador', 'Egypt', 'El Salvador', 'England',
#        'FR Yugoslavia', 'France', 'Germany', 'Ghana', 'Greece', 'Haiti',
#        'Honduras', 'Hungary', 'Iceland', 'Iran', 'Iraq', 'Israel', 'Italy',
#        'Ivory Coast', 'Jamaica', 'Japan', 'Kuwait', 'Mexico', 'Morocco',
#        'Netherlands', 'New Zealand', 'Nigeria', 'North Korea',
#        'Northern Ireland', 'Norway', 'Panama', 'Paraguay', 'Peru', 'Poland',
#        'Portugal', 'Republic of Ireland', 'Romania', 'Russia', 'Saudi Arabia',
#        'Scotland', 'Senegal', 'Serbia', 'Serbia and Montenegro', 'Slovakia',
#        'Slovenia', 'South Africa', 'South Korea', 'Soviet Union', 'Spain',
# ...

# %%
from scipy.stats import poisson

# %%
def predict_points(home,away):
  if home in df_team_strength.index and away in df_team_strength.index:
    # lambda goals_scored * goals_conceded
    lamb_home =  df_team_strength.at[home,'GoalsScored']*df_team_strength.at[away,'GoalsConceded']
    lamb_away =  df_team_strength.at[away,'GoalsScored']*df_team_strength.at[home,'GoalsConceded']
    prob_home,prob_away, prob_draw=0,0,0
    for x in range(0,11): # numero de goles del equipo local
      for y in range(0,11): #  numero de goles del equipo visitante
        p = poisson.pmf(x,lamb_home)*poisson.pmf(y,lamb_away)
        if x>y:
          prob_home +=p
        elif x==y:
          prob_draw +=p
        else:
          prob_away +=p

    points_home = 3*prob_home+prob_draw
    points_away = 3*prob_away + prob_draw
    return (points_home,points_away)
  else:
    return (0,0)

# %% [markdown]
# ## **TEST_FUNCTION**

# %%
predict_points('England','United States')
# Out:
# (2.1677885515423205, 0.6528734333051367)

# %%
predict_points('Argentina','Mexico')
# Out:
# (2.319527107953938, 0.5332248445655723)

# %%
predict_points('Argentina','Saudi Arabia')
# Out:
# (2.7856734119856896, 0.14461198044672569)

# %%
df_fixture
# Out:
#     Unnamed: 0              home     score              away  year
# 0            0             Qatar   Match 1           Ecuador  2022
# 1            1           Senegal   Match 2       Netherlands  2022
# 2            2             Qatar  Match 18           Senegal  2022
# 3            3       Netherlands  Match 19           Ecuador  2022
# 4            4           Ecuador  Match 35           Senegal  2022
# ..         ...               ...       ...               ...   ...
# 59          59  Winners Match 51  Match 59  Winners Match 52  2022
# 60          60  Winners Match 57  Match 61  Winners Match 58  2022
# 61          61  Winners Match 59  Match 62  Winners Match 60  2022
# 62          62   Losers Match 61  Match 63   Losers Match 62  2022
# 63          63  Winners Match 61  Match 64  Winners Match 62  2022
#
# [64 rows x 5 columns]

# %% [markdown]
# ## **PREDICTION WORLD CUP**

# %%
df_fixture_group_48 = df_fixture[:48].copy()

# %%
print(df_fixture_group_48)
# Out:
#     Unnamed: 0           home     score           away  year
# 0            0          Qatar   Match 1        Ecuador  2022
# 1            1        Senegal   Match 2    Netherlands  2022
# 2            2          Qatar  Match 18        Senegal  2022
# 3            3    Netherlands  Match 19        Ecuador  2022
# 4            4        Ecuador  Match 35        Senegal  2022
# 5            5    Netherlands  Match 36          Qatar  2022
# 6            6        England   Match 3           Iran  2022
# 7            7  United States   Match 4          Wales  2022
# 8            8          Wales  Match 17           Iran  2022
# 9            9        England  Match 20  United States  2022
# 10          10          Wales  Match 33        England  2022
# 11          11           Iran  Match 34  United States  2022
# 12          12      Argentina   Match 8   Saudi Arabia  2022
# 13          13         Mexico   Match 7         Poland  2022
# ...

# %%
df_fixture_knockout = df_fixture[48:56].copy()

# %%
df_fixture_knockout
# Out:
#     Unnamed: 0             home     score                away  year
# 48          48  Winners Group A  Match 49  Runners-up Group B  2022
# 49          49  Winners Group C  Match 50  Runners-up Group D  2022
# 50          50  Winners Group D  Match 52  Runners-up Group C  2022
# 51          51  Winners Group B  Match 51  Runners-up Group A  2022
# 52          52  Winners Group E  Match 53  Runners-up Group F  2022
# 53          53  Winners Group G  Match 54  Runners-up Group H  2022
# 54          54  Winners Group F  Match 55  Runners-up Group E  2022
# 55          55  Winners Group H  Match 56  Runners-up Group G  2022

# %%
df_fixture_quarter = df_fixture[56:60].copy()

# %%
df_fixture_quarter
# Out:
#     Unnamed: 0              home     score              away  year
# 56          56  Winners Match 53  Match 58  Winners Match 54  2022
# 57          57  Winners Match 49  Match 57  Winners Match 50  2022
# 58          58  Winners Match 55  Match 60  Winners Match 56  2022
# 59          59  Winners Match 51  Match 59  Winners Match 52  2022

# %%
df_fixture_semi = df_fixture[60:62].copy()

# %%
df_fixture_semi
# Out:
#     Unnamed: 0              home     score              away  year
# 60          60  Winners Match 57  Match 61  Winners Match 58  2022
# 61          61  Winners Match 59  Match 62  Winners Match 60  2022

# %%
df_fixture_final=df_fixture[62:].copy()

# %%
df_fixture_final
# Out:
#     Unnamed: 0              home     score              away  year
# 62          62   Losers Match 61  Match 63   Losers Match 62  2022
# 63          63  Winners Match 61  Match 64  Winners Match 62  2022

# %%
dict_table
# Out:
# {'Group A':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1    Qatar (H)    0  0  0  0   0   0   0    0
#  1    2      Ecuador    0  0  0  0   0   0   0    0
#  2    3      Senegal    0  0  0  0   0   0   0    0
#  3    4  Netherlands    0  0  0  0   0   0   0    0,
#  'Group B':    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1        England    0  0  0  0   0   0   0    0
#  1    2           Iran    0  0  0  0   0   0   0    0
#  2    3  United States    0  0  0  0   0   0   0    0
#  3    4          Wales    0  0  0  0   0   0   0    0,
#  'Group C':    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     Argentina    0  0  0  0   0   0   0    0
#  1    2  Saudi Arabia    0  0  0  0   0   0   0    0
#  2    3        Mexico    0  0  0  0   0   0   0    0
#  3    4        Poland    0  0  0  0   0   0   0    0,
#  'Group D':    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     France    0  0  0  0   0   0   0    0
# ...

# %%
# CORRECION DEL NOMBRE Qatar (H)por solos Qatar

# %%
dict_table['Group A']['Team'].values[0]= 'Qatar'

# %%
dict_table
# Out:
# {'Group A':    Pos         Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1        Qatar    0  0  0  0   0   0   0    0
#  1    2      Ecuador    0  0  0  0   0   0   0    0
#  2    3      Senegal    0  0  0  0   0   0   0    0
#  3    4  Netherlands    0  0  0  0   0   0   0    0,
#  'Group B':    Pos           Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1        England    0  0  0  0   0   0   0    0
#  1    2           Iran    0  0  0  0   0   0   0    0
#  2    3  United States    0  0  0  0   0   0   0    0
#  3    4          Wales    0  0  0  0   0   0   0    0,
#  'Group C':    Pos          Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     Argentina    0  0  0  0   0   0   0    0
#  1    2  Saudi Arabia    0  0  0  0   0   0   0    0
#  2    3        Mexico    0  0  0  0   0   0   0    0
#  3    4        Poland    0  0  0  0   0   0   0    0,
#  'Group D':    Pos       Team  Pld  W  D  L  GF  GA  GD  Pts
#  0    1     France    0  0  0  0   0   0   0    0
# ...

# %% [markdown]
# # UTILIZANDO EL DICTIONARIO dict_table hagamos el recorrido de los grupos, primeras pruebas

# %%
for group in dict_table:
  print(group)
  print(dict_table[group]['Team'].values)
# Out:
# Group A
# ['Qatar' 'Ecuador' 'Senegal' 'Netherlands']
# Group B
# ['England' 'Iran' 'United States' 'Wales']
# Group C
# ['Argentina' 'Saudi Arabia' 'Mexico' 'Poland']
# Group D
# ['France' 'Australia' 'Denmark' 'Tunisia']
# Group E
# ['Spain' 'Costa Rica' 'Germany' 'Japan']
# Group F
# ['Belgium' 'Canada' 'Morocco' 'Croatia']
# Group G
# ['Brazil' 'Serbia' 'Switzerland' 'Cameroon']
# Group H
# ['Portugal' 'Ghana' 'Uruguay' 'South Korea']

# %% [markdown]
# ## TENGAMOS PRESENTE QUE DE LOS 48 PARTIDOS SE JUEGAN 6 PARTIDOS EN CADA GRUPO

# %%
print(df_fixture_group_48)
# Out:
#     Unnamed: 0           home     score           away  year
# 0            0          Qatar   Match 1        Ecuador  2022
# 1            1        Senegal   Match 2    Netherlands  2022
# 2            2          Qatar  Match 18        Senegal  2022
# 3            3    Netherlands  Match 19        Ecuador  2022
# 4            4        Ecuador  Match 35        Senegal  2022
# 5            5    Netherlands  Match 36          Qatar  2022
# 6            6        England   Match 3           Iran  2022
# 7            7  United States   Match 4          Wales  2022
# 8            8          Wales  Match 17           Iran  2022
# 9            9        England  Match 20  United States  2022
# 10          10          Wales  Match 33        England  2022
# 11          11           Iran  Match 34  United States  2022
# 12          12      Argentina   Match 8   Saudi Arabia  2022
# 13          13         Mexico   Match 7         Poland  2022
# ...

# %%
group='Group A'
teams_in_group= dict_table[group]['Team'].values
df_fixture_group_6= df_fixture_group_48[df_fixture_group_48['home'].isin(teams_in_group)]# filtrar los equipos que estan dentro del grupo
print(df_fixture_group_6)
# Out:
#    Unnamed: 0         home     score         away  year
# 0           0        Qatar   Match 1      Ecuador  2022
# 1           1      Senegal   Match 2  Netherlands  2022
# 2           2        Qatar  Match 18      Senegal  2022
# 3           3  Netherlands  Match 19      Ecuador  2022
# 4           4      Ecuador  Match 35      Senegal  2022
# 5           5  Netherlands  Match 36        Qatar  2022

# %% [markdown]
# ## GROUP STAGE

# %%
for group in dict_table:
    teams_in_group = dict_table[group]['Team'].values
    df_fixture_group_6 = df_fixture_group_48[df_fixture_group_48['home'].isin(teams_in_group)]
    for index, row in df_fixture_group_6.iterrows():
        home, away = row['home'], row['away']
        points_home, points_away = predict_points(home, away)
        dict_table[group].loc[dict_table[group]['Team'] == home, 'Pts'] += points_home
        dict_table[group].loc[dict_table[group]['Team'] == away, 'Pts'] += points_away

    dict_table[group] = dict_table[group].sort_values('Pts', ascending=False).reset_index()
    dict_table[group] = dict_table[group][['Team', 'Pts']]
    dict_table[group] = dict_table[group].round(0)

# %%
dict_table['Group A']
# Out:
#           Team  Pts
# 0  Netherlands  4.0
# 1      Senegal  2.0
# 2      Ecuador  2.0
# 3        Qatar  0.0

# %% [markdown]
# ## KNOCK OUT

# %%
df_fixture_knockout
# Out:
#     Unnamed: 0             home     score                away  year
# 48          48  Winners Group A  Match 49  Runners-up Group B  2022
# 49          49  Winners Group C  Match 50  Runners-up Group D  2022
# 50          50  Winners Group D  Match 52  Runners-up Group C  2022
# 51          51  Winners Group B  Match 51  Runners-up Group A  2022
# 52          52  Winners Group E  Match 53  Runners-up Group F  2022
# 53          53  Winners Group G  Match 54  Runners-up Group H  2022
# 54          54  Winners Group F  Match 55  Runners-up Group E  2022
# 55          55  Winners Group H  Match 56  Runners-up Group G  2022

# %%
for group in dict_table:
    group_winner = dict_table[group].loc[0, 'Team']
    runners_up = dict_table[group].loc[1, 'Team']
    df_fixture_knockout.replace({f'Winners {group}':group_winner,
                                 f'Runners-up {group}':runners_up}, inplace=True)

df_fixture_knockout['winner'] = '?'
df_fixture_knockout
# Out:
#     Unnamed: 0         home     score         away  year winner
# 48          48  Netherlands  Match 49        Wales  2022      ?
# 49          49    Argentina  Match 50      Denmark  2022      ?
# 50          50       France  Match 52       Poland  2022      ?
# 51          51      England  Match 51      Senegal  2022      ?
# 52          52      Germany  Match 53      Belgium  2022      ?
# 53          53       Brazil  Match 54      Uruguay  2022      ?
# 54          54      Croatia  Match 55        Spain  2022      ?
# 55          55     Portugal  Match 56  Switzerland  2022      ?

# %%
# creamos el metodo get_winner
def get_winner(df_fixture_updated):
    for index, row in df_fixture_updated.iterrows():
        home, away = row['home'], row['away']
        points_home, points_away = predict_points(home, away)
        if points_home > points_away:
            winner = home
        else:
            winner = away
        df_fixture_updated.loc[index, 'winner'] = winner
    return df_fixture_updated

# %%
get_winner(df_fixture_knockout)
# Out:
#     Unnamed: 0         home     score         away  year       winner
# 48          48  Netherlands  Match 49        Wales  2022  Netherlands
# 49          49    Argentina  Match 50      Denmark  2022    Argentina
# 50          50       France  Match 52       Poland  2022       France
# 51          51      England  Match 51      Senegal  2022      England
# 52          52      Germany  Match 53      Belgium  2022      Germany
# 53          53       Brazil  Match 54      Uruguay  2022       Brazil
# 54          54      Croatia  Match 55        Spain  2022      Croatia
# 55          55     Portugal  Match 56  Switzerland  2022     Portugal

# %% [markdown]
# ## QUARTER FINAL

# %%
def update_table(df_fixture_round_1, df_fixture_round_2):
    for index, row in df_fixture_round_1.iterrows():
        winner = df_fixture_round_1.loc[index, 'winner']
        match = df_fixture_round_1.loc[index, 'score']
        df_fixture_round_2.replace({f'Winners {match}':winner}, inplace=True)
    df_fixture_round_2['winner'] = '?'
    return df_fixture_round_2

# %%
update_table(df_fixture_knockout, df_fixture_quarter)
# Out:
#     Unnamed: 0         home     score       away  year winner
# 56          56      Germany  Match 58     Brazil  2022      ?
# 57          57  Netherlands  Match 57  Argentina  2022      ?
# 58          58      Croatia  Match 60   Portugal  2022      ?
# 59          59      England  Match 59     France  2022      ?

# %%
get_winner(df_fixture_quarter)
# Out:
#     Unnamed: 0         home     score       away  year       winner
# 56          56      Germany  Match 58     Brazil  2022       Brazil
# 57          57  Netherlands  Match 57  Argentina  2022  Netherlands
# 58          58      Croatia  Match 60   Portugal  2022     Portugal
# 59          59      England  Match 59     France  2022       France

# %% [markdown]
# ## SEMIFINAL

# %%
update_table(df_fixture_quarter, df_fixture_semi)
# Out:
#     Unnamed: 0         home     score      away  year winner
# 60          60  Netherlands  Match 61    Brazil  2022      ?
# 61          61       France  Match 62  Portugal  2022      ?

# %%
get_winner(df_fixture_semi)
# Out:
#     Unnamed: 0         home     score      away  year  winner
# 60          60  Netherlands  Match 61    Brazil  2022  Brazil
# 61          61       France  Match 62  Portugal  2022  France

# %% [markdown]
# ## FINAL DEL MUNDIAL

# %%
update_table(df_fixture_semi, df_fixture_final)
# Out:
#     Unnamed: 0             home     score             away  year winner
# 62          62  Losers Match 61  Match 63  Losers Match 62  2022      ?
# 63          63           Brazil  Match 64           France  2022      ?

# %%
get_winner(df_fixture_final)
# Out:
#     Unnamed: 0             home     score             away  year  \
# 62          62  Losers Match 61  Match 63  Losers Match 62  2022
# 63          63           Brazil  Match 64           France  2022
#
#              winner
# 62  Losers Match 62
# 63           Brazil

# %% [markdown]
# ---

# %% [markdown]
#  **EL MODELO PREDICE QUE EL GANADOR SERIA BRAZIL**

# %% [markdown]
# **El desarrollo presentado indica que los equipos que deberian llegar a la final son BRAZIL Y FRANCIA y que el ganador seria Brazil**

# %% [markdown]
# ---

# %% [markdown]
# # NOTA SOBRE PICKLE

# %% [markdown]
# El módulo Pickle de Python es un popular formato utilizado para serializar y deserializar tipos de datos. Este formato es nativo de Python, lo que significa que los objetos Pickle no pueden cargarse utilizando ningún otro lenguaje de programación.
#
# Pickle tiene sus propias ventajas e inconvenientes en comparación con otros formatos de serialización.
#
# **Ventajas de utilizar Pickle para serializar objetos**
#
#
# A diferencia de formatos de serialización como JSON, que no pueden gestionar tuplas y objetos datetime, Pickle puede serializar casi todos los tipos de datos integrados de Python de uso común. También conserva el estado exacto del objeto, cosa que JSON no puede hacer.
# Pickle también es una buena opción para almacenar estructuras recursivas, ya que solo escribe un objeto una vez.
# Pickle ofrece flexibilidad a la hora de deserializar objetos. Puedes guardar fácilmente distintas variables en un archivo Pickle y volver a cargarlas en otra sesión de Python, recuperando tus datos exactamente como estaban sin tener que editar tu código.
#
#
# **Desventajas de utilizar Pickle**
#
#
# Pickle no es seguro porque puede ejecutar callables Python maliciosos para construir objetos. Al deserializar un objeto, Pickle no puede distinguir entre un callable malicioso y uno no malicioso. Debido a esto, los usuarios pueden acabar ejecutando código arbitrario durante la deserialización.
# Como ya se ha mencionado, Pickle es un módulo específico de Python, y puede que te cueste deserializar objetos pickled cuando utilices un lenguaje diferente.
# Según varias pruebas comparativas, Pickle parece ser más lento y produce valores serializados mayores que formatos como JSON y ApacheThrift.
