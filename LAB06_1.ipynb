# %%
# Importar las librerías necesarias
import pandas as pd
# Cargar los datos
data_path = '/content/drive/MyDrive/TOULOUSE_PRUEBAS/SQL2/social_media_influencers_Youtube112022.csv'
data = pd.read_csv(data_path)
df = pd.DataFrame(data)
df
# Out:
#      s.no    Youtube channel               youtuber name         Category  \
# 0       1            tseries                    T-Series    Music & Dance
# 1       2          checkgate  Cocomelon - Nursery Rhymes        Education
# 2       3          PewDiePie                   PewDiePie        Animation
# 3       4        MrBeast6000                     MrBeast      Video games
# 4       5  ✿ Kids Diana Show           ✿ Kids Diana Show        Animation
# ..    ...                ...                         ...              ...
# 995   996               RUOK                        RUOK              NaN
# 996   997     FoxNewsChannel                    Fox News  News & Politics
# 997   998   SULE PRODUCTIONS            SULE PRODUCTIONS              NaN
# 998   999            MBCkpop                     MBCkpop    Music & Dance
# 999  1000      Dynamo Gaming               Dynamo Gaming              NaN
#
#     Followers        Country \nViews (Avg.) Likes (Avg.) Comments (Avg.)  \
# ...

# %%
#Los x primeros
df.head(2)
# Out:
#    s.no Youtube channel               youtuber name       Category Followers  \
# 0     1         tseries                    T-Series  Music & Dance    229.5M
# 1     2       checkgate  Cocomelon - Nursery Rhymes      Education    146.6M
#
#   Country \nViews (Avg.) Likes (Avg.) Comments (Avg.) Category-2
# 0   India         103.8K         2.8K             158        NaN
# 1     NaN           9.5M        48.3K               0        NaN

# %%
#Los x ultimos
df.tail(2)
# Out:
#      s.no Youtube channel  youtuber name       Category Followers   Country  \
# 998   999         MBCkpop        MBCkpop  Music & Dance     10.1M  Malaysia
# 999  1000   Dynamo Gaming  Dynamo Gaming            NaN     10.1M     India
#
#     \nViews (Avg.) Likes (Avg.) Comments (Avg.) Category-2
# 998          19.7K         2.6K              92        NaN
# 999         139.6K        15.4K             125        NaN

# %%
#Crear un subconjunto
subconjunto = df[['Youtube channel', 'Country']]
subconjunto
# Out:
#        Youtube channel        Country
# 0              tseries          India
# 1            checkgate            NaN
# 2            PewDiePie  United States
# 3          MrBeast6000  United States
# 4    ✿ Kids Diana Show            NaN
# ..                 ...            ...
# 995               RUOK         Brazil
# 996     FoxNewsChannel  United States
# 997   SULE PRODUCTIONS      Indonesia
# 998            MBCkpop       Malaysia
# 999      Dynamo Gaming          India
#
# [1000 rows x 2 columns]

# %%
#Orden
#df_ordenado = df.sort_values(by='Followers', ascending=True)
df_ordenado = df.sort_values(by='Followers', ascending=False)
df_ordenado
# Out:
#      s.no       Youtube channel         youtuber name         Category  \
# 6       7          WWEFanNation                   WWE      Video games
# 7       8       zeemusiccompany     Zee Music Company    Music & Dance
# 8       9         Vlad and Niki         Vlad and Niki        Animation
# 9      10             BLACKPINK             BLACKPINK    Music & Dance
# 10     11    GoldminesTelefilms             Goldmines              NaN
# ..    ...                   ...                   ...              ...
# 993   994         HiTechIslamic  Hi-Tech Islamic Naat    Music & Dance
# 992   993            Heera Gold            Heera Gold      Daily vlogs
# 991   992  Sab Kuchh Sekho Jano  Sab Kuchh Sekho Jano  News & Politics
# 989   990           OneRepublic           OneRepublic    Music & Dance
# 999  1000         Dynamo Gaming         Dynamo Gaming              NaN
#
#     Followers        Country \nViews (Avg.) Likes (Avg.) Comments (Avg.)  \
# ...

# %%
# Agrupar el dataframe por una columna
conteo_por_ciudad = df.groupby('Category')['s.no'].size()
conteo_por_ciudad
# Out:
# Category
# ASMR                      2
# Animals & Pets            2
# Animation                98
# Beauty                    1
# DIY & Life Hacks         10
# Daily vlogs              38
# Design/art                1
# Education                31
# Fashion                   2
# Fitness                   3
# Food & Drinks            14
# Health & Self Help        3
# Humor                    12
# Movies                  100
# Music & Dance           238
# News & Politics          44
# Science & Technology     17
# Sports                   10
# Toys                     19
# Video games              62
# Name: s.no, dtype: int64

# %%
#Adicionar columna
df['Sueldotemp'] = 7000
df['Salary'] = df['Sueldotemp'] * 10
df
# Out:
#      s.no    Youtube channel               youtuber name         Category  \
# 0       1            tseries                    T-Series    Music & Dance
# 1       2          checkgate  Cocomelon - Nursery Rhymes        Education
# 2       3          PewDiePie                   PewDiePie        Animation
# 3       4        MrBeast6000                     MrBeast      Video games
# 4       5  ✿ Kids Diana Show           ✿ Kids Diana Show        Animation
# ..    ...                ...                         ...              ...
# 995   996               RUOK                        RUOK              NaN
# 996   997     FoxNewsChannel                    Fox News  News & Politics
# 997   998   SULE PRODUCTIONS            SULE PRODUCTIONS              NaN
# 998   999            MBCkpop                     MBCkpop    Music & Dance
# 999  1000      Dynamo Gaming               Dynamo Gaming              NaN
#
#     Followers        Country \nViews (Avg.) Likes (Avg.) Comments (Avg.)  \
# ...

# %%
#Adiciona columna en una posicion
df.insert(2, 'Salary2', df['Salary'] * 5)
df
# Out:
#      s.no    Youtube channel  Salary2               youtuber name  \
# 0       1            tseries   350000                    T-Series
# 1       2          checkgate   350000  Cocomelon - Nursery Rhymes
# 2       3          PewDiePie   350000                   PewDiePie
# 3       4        MrBeast6000   350000                     MrBeast
# 4       5  ✿ Kids Diana Show   350000           ✿ Kids Diana Show
# ..    ...                ...      ...                         ...
# 995   996               RUOK   350000                        RUOK
# 996   997     FoxNewsChannel   350000                    Fox News
# 997   998   SULE PRODUCTIONS   350000            SULE PRODUCTIONS
# 998   999            MBCkpop   350000                     MBCkpop
# 999  1000      Dynamo Gaming   350000               Dynamo Gaming
#
#             Category Followers        Country \nViews (Avg.) Likes (Avg.)  \
# 0      Music & Dance    229.5M          India         103.8K         2.8K
# ...

# %%
# Elimine la columna 'Salary2' por nombre
df.drop('Salary2', axis=1, inplace=True)  # axis=1 indica eliminar columna, inplace=True modifica el DataFrame original

df
# Out:
#      s.no    Youtube channel               youtuber name         Category  \
# 0       1            tseries                    T-Series    Music & Dance
# 1       2          checkgate  Cocomelon - Nursery Rhymes        Education
# 2       3          PewDiePie                   PewDiePie        Animation
# 3       4        MrBeast6000                     MrBeast      Video games
# 4       5  ✿ Kids Diana Show           ✿ Kids Diana Show        Animation
# ..    ...                ...                         ...              ...
# 995   996               RUOK                        RUOK              NaN
# 996   997     FoxNewsChannel                    Fox News  News & Politics
# 997   998   SULE PRODUCTIONS            SULE PRODUCTIONS              NaN
# 998   999            MBCkpop                     MBCkpop    Music & Dance
# 999  1000      Dynamo Gaming               Dynamo Gaming              NaN
#
#     Followers        Country \nViews (Avg.) Likes (Avg.) Comments (Avg.)  \
# ...
